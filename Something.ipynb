# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.by import By
#Setting the website
path ="C:\Python310\chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get('https://s.cafef.vn/Lich-su-giao-dich-FPT-1.chn')

inner_html = driver.find_element_by_xpath("//table[@id='GridTable2']")
print(inner_html)
driver.close()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23064\2115296029.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23064\2115296029.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   inner_html = driver.find_element_by_xpath("//table[@id='GridTable2']")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\DELL\OneDrive - RMIT University\Documents\Python Code\WebScraping Projects\Something.ipynb Cell 1' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive%20-%20RMIT%20University/Documents/Python%20Code/WebScraping%20Projects/Something.ipynb#ch0000002?line=5'>6</a> driver = webdriver.Chrome(path)
# ...

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

URL = "https://s.cafef.vn/Lich-su-giao-dich-FPT-1.chn"
page = requests.get(URL)
soup = bs(page.content, "lxml")

# %%
r = requests.get("https://s.cafef.vn/Lich-su-giao-dich-FPT-1.chn")
soup = bs(r.content,"lxml")

print(soup.select('tr[id]'))
# Out:
# [<tr id="ctl00_ContentPlaceHolder1_ctl03_rptData2_ctl01_itemTR" style="font-family: Arial; font-size: 10px; font-weight: normal; background-color: #FFF;height:30px;padding-right:5px">
# <td class="Item_DateItem">10/06/2022</td>
# <td class="Item_Price10" id="ctl00_ContentPlaceHolder1_ctl03_rptData2_ctl01_Td5">0.00 </td>
# <td class="Item_Price10">110.00 </td>
# <td class="Item_ChangePrice"><span class="Index_Down">-5.30 (-4.60 %)</span></td>
# <td class="Item_Image"> <img align="absmiddle" src="https://cafef1.mediacdn.vn/static/images/Scontrols/Images/LSG/down_.gif"/>   </td>
# <td class="Item_Price10">2,972,500 </td>
# <td class="Item_Price10">335,330,000,000 </td>
# <td class="Item_Price10">1,159,100 </td>
# <td class="LastItem_Price">142,917,030,000 </td>
# <td class="Item_Price10">113.40 </td>
# <td class="Item_Price10">114.70 </td>
# <td class="Item_Price10">110.00 </td>
# <td class="Item_Price10" style="display:none;">0 </td>
# ...
